# %%
import sys
# !conda install -c conda-forge -y --prefix {sys.prefix} spacy
# Out:
# Retrieving notices: ...working... done
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/yudong-gu/opt/anaconda3
#
#   added / updated specs:
#     - spacy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     spacy-3.5.1                |   py39h6dc771e_0         4.6 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         4.6 MB
#
# The following packages will be UPDATED:
#
#   spacy                                3.5.0-py39h6dc771e_0 --> 3.5.1-py39h6dc771e_0
#
#
#
# ...
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
import spacy

# %%
import random

# %%
# !{sys.executable} -m spacy download en_core_web_md
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 MB 38.4 MB/s eta 0:00:0000:0100:01
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')

# %%
nlp = spacy.load('en_core_web_md')

# %%
text = open("theBlueCastle.txt").read()

# %%
doc = nlp(text)

# %%
words = [w for w in list(doc) if w.is_alpha]

# %%
noun_chunks = list(doc.noun_chunks)

# %%
entities
# Out:
# [The Blue Castle,
#  Lucy Maud Montgomery,
#  the United States,
#  the United States,
#  Lucy Maud Montgomery
#  ,
#  May 3, 2022,
#  English,
#  Laura Natal Rodrigues,
#  Hathi Trust Digital Library,
#  BY
#  L. M. MONTGOMERY
#  ,
#  NEW YORK,
#  XXXII,
#  XXXV,
#  XLI
#   ,
#  XLII
#   ,
#  THE BLUE CASTLE
#
#
#
#  ,
#  May,
#  Valancy Stirling,
#  Wellington,
#  Trent,
#  Montreal,
#  one,
#  twenty-nine,
#  Deerwood,
#  Stirlings,
#  Romance,
#  twenty-nine,
#  Uncle Wellington,
#  two,
#  one,
#  Cousin Stickles,
#  half,
#  one,
#  Stirling,
#  only two,
#  One,
#  Queen Louise,
#  Wellington,
#  tenth,
#  nineteen years,
#  Queen Louise,
#  Cousin Stickles,
#  Stirling,
#  days,
#  night,
#  Frederick Stirling,
#  Cousin Stickles,
#  the Blue Castle,
#  Stirling,
#  Cousin Stickles,
#  two,
#  Elm Street,
#  the Blue
#  Castle,
#  Spain,
#  Blue Castle,
#  night,
#  Stirlings,
#  half,
#  Blue Castle,
#  one,
#  One,
#  the Blue Castle,
#  twelve,
#  fifteen,
#  twenty,
# ...

# %%
entities = list(doc.ents)

# %%
nouns = [w for w in words if w.pos_ == "NOUN"]
verbs = [w for w in words if w.pos_ == "VERB"]
adjs = [w for w in words if w.pos_ == "ADJ"]
advs = [w for w in words if w.pos_ == "ADV"]

# %%
people = [item for item in entities if item.label_ == "PERSON"]
facility = [item for item in entities if item.label_ == "FAC"]
product = [item for item in entities if item.label_ == "PRODUCT"]
date = [item for item in entities if item.label_ == "DATE"]
ordinal = [item for item in entities if item.label_ == "ORDINAL"]

# %%
people
# Out:
# [Lucy Maud Montgomery,
#  Lucy Maud Montgomery
#  ,
#  Laura Natal Rodrigues,
#  BY
#  L. M. MONTGOMERY
#  ,
#  XLI
#   ,
#  XLII
#   ,
#  Valancy Stirling,
#  Trent,
#  Deerwood,
#  Romance,
#  Cousin Stickles,
#  Stirling,
#  Queen Louise,
#  Queen Louise,
#  Cousin Stickles,
#  Stirling,
#  Frederick Stirling,
#  Cousin Stickles,
#  Cousin Stickles,
#  Aunt,
#  Uncle Wellington,
#  Uncle Wellington,
#  Aunt
#  Wellington,
#  Valancy,
#  Olive,
#  Cecil,
#  Aunt Wellington,
#  Aunt
#  Wellington,
#  Aunt Wellington,
#  Aunt Alberta,
#  Uncle Herbert,
#  Doss,
#  Doss,
#  James,
#  Valancy,
#  Uncle Benjamin,
#  Doss,
#  Doss,
#  Uncle Benjamin,
#  Valancy,
#  Uncle Benjamin’s,
#  Georgiana,
#  George the Fourth,
#  Aunt Mildred,
#  Olive,
#  Cousin
#  Stickles,
#  Banquo,
#  Aunt Wellington,
#  John Foster,
#  John Foster,
#  Frederick Stirling—“all,
#  John Foster’s,
#  John Foster’s,
#  Valancy,
#  John Foster,
#  Clarkson,
#  Foster,
#  John Foster,
#  John
#  Foster,
# ...

# %%
nouns
# Out:
# [use,
#  parts,
#  world,
#  cost,
#  restrictions,
#  terms,
#  eBook,
#  laws,
#  country,
#  Title,
#  novel,
#  Author,
#  Date,
#  eBook,
#  Language,
#  Images,
#  PROJECT,
#  GUTENBERG,
#  CASTLE,
#  CONTENTS,
#  CHAPTER,
#  CHAPTER,
#  III,
#  V,
#  CHAPTER,
#  IX,
#  X,
#  XIII,
#  XIX,
#  CHAPTER,
#  CHAPTER,
#  XXX,
#  CHAPTER,
#  CHAPTER,
#  XXXVIII,
#  CHAPTER,
#  morning,
#  life,
#  rest,
#  clan,
#  engagement,
#  picnic,
#  rain,
#  hour,
#  dawn,
#  morrow,
#  community,
#  connection,
#  man,
#  maidenhood,
#  hope,
#  way,
#  morning,
#  fact,
#  man,
#  sting,
#  maid,
#  maid,
#  chance,
#  maid,
#  man,
#  tears,
#  eyes,
#  darkness,
#  reasons,
#  attack,
#  pain,
#  heart,
#  spell,
#  bed,
#  mother,
#  eyes,
#  breakfast,
#  questions,
#  cause,
#  grin,
#  truth,
#  day,
#  life,
#  daughter,
#  course,
#  appearances,
#  mother,
#  voice,
#  maidenly,
#  men,
#  thought,
#  mother,
#  expression,
#  laugh,
#  sense,
#  humour,
#  clan,
#  matter,
# ...

# %%
facility
# Out:
# [the Blue Castle,
#  Elm Street,
#  Blue Castle,
#  Blue Castle,
#  the Blue Castle,
#  Blue Castle,
#  Blue Castle,
#  Blue Castle,
#  Wansbarra,
#  Blue Castle,
#  Stirling,
#  Blue Castle,
#  the Blue Castle,
#  Elm Street,
#  Elm Street,
#  Elm Street,
#  Blue Castle,
#  Maple Avenue,
#  Blue Castle,
#  the Port
#  Lawrence Prices,
#  Blue Castle,
#  Port Lawrence,
#  the lawn gate,
#  St. Andrew,
#  Blue Castle,
#  Blue Castle,
#  Blue Castle,
#  Blue Castle,
#  Blue Castle,
#  the Blue Castle,
#  Elm Street,
#  Elm Street,
#  Chidley Corners,
#  Blue Castle,
#  Port,
#  Blue Castle,
#  the Stirling gate Valancy,
#  Blue Castle,
#  the Blue Castle,
#  the Blue Castle,
#  Blue Castle,
#  the Blarney Stone,
#  the Blue Castle,
#  Blue Castle,
#  the Blue Castle,
#  Blue Castle,
#  the Blue Castle,
#  the Blue Castle,
#  Blue Castle,
#  Port Lawrence,
#  Sterlings,
#  the Blue Castle,
#  Blue Castle,
#  Elm Street,
#  the Blue Castle,
#  the Blue Castle,
#  Port Lawrence,
# ...

# %%
date
# Out:
# [May 3, 2022,
#  May,
#  nineteen years,
#  days,
#  fifteen,
#  twenty,
#  twenty-nine,
#  wintry,
#  eighty years,
#  that day,
#  annual,
#  thirty
#  years before,
#  late years,
#  the same day,
#  today,
#  these days,
#  six years ago,
#  this year,
#  the sacred day,
#  years ago,
#  the last year,
#  several years,
#  a month,
#  years,
#  the day,
#  ten
#  years before,
#  half-past,
#  half-past seven,
#  six, year in and year,
#  all day,
#  May,
#  May,
#  October,
#  the twenty-first of October,
#  twenty-first,
#  October,
#  first
#  year,
#  twentieth of October,
#  the next day,
#  late years,
#  the day,
#  every winter,
#  winter,
#  November to May,
#  June,
#  twenty-nine years,
#  twenty-nine,
#  nine years,
#  that day,
#  Sundays,
#  spring,
#  summer,
#  autumn,
#  winter,
#  only last week,
#  four weeks,
#  Four weeks,
#  more than two weeks,
#  a damp day,
#  two years ago,
#  June,
#  today,
#  three-year-old,
#  summer,
#  twenty-ninth,
# ...

# %%
print(random.sample(people, 1) + random.sample(verbs, 1) + random.sample(date, 1))
print("...")
print(random.sample(ordinal, 1)+random.sample(nouns, 3))
print("..")
print(random.sample(nouns, 1))
print(".")
print("\n")
print(random.sample(people, 1) + random.sample(verbs, 1) + random.sample(date, 1))
print("...")
print(random.sample(adjs, 1)+random.sample(nouns, 3))
print("..")
print(random.sample(facility, 1))
print(".")
print("\n")
print(random.sample(nouns, 1) + random.sample(verbs, 1) + random.sample(nouns, 1))
print("...")
print(random.sample(verbs, 1)+random.sample(advs, 1))
print("..")
print(random.sample(nouns, 1))
print(".")
print("\n")
print(random.sample(nouns, 1) + random.sample(verbs, 1) + random.sample(nouns, 1))
print("...")
print(random.sample(verbs, 1)+random.sample(advs, 1))
print("..")
print(random.sample(nouns, 1))
print(".")
print("\n")
print(random.sample(nouns, 1) + random.sample(verbs, 1) + random.sample(nouns, 1))
print("...")
print(random.sample(verbs, 1)+random.sample(advs, 1))
print("..")
print(random.sample(nouns, 1))
print(".")
print("\n")
print(random.sample(nouns, 1) + random.sample(verbs, 1) + random.sample(nouns, 1))
print("...")
print(random.sample(verbs, 1)+random.sample(advs, 1))
print("..")
print(random.sample(nouns, 1))
print(".")
# Out:
# [Barney Snaith, gone, 1.E.3]
# ...
# [first, amazement, curve, death]
# ..
# [door]
# .
#
#
# [Uncle Benjamin, distributed, Friday]
# ...
# [uplifted, hat, pangs, people]
# ..
# [the Blue Castle]
# .
#
#
# [troubles, going, wreath]
# ...
# [went, all]
# ..
# [church]
# .
#
#
# [step, wondered, door]
# ...
# [did, up]
# ..
# [man]
# .
#
#
# [joke, throve, emotions]
# ...
# [Roaring, Too]
# ..
# [room]
# .
#
#
# [miles, retorted, way]
# ...
# [stay, properly]
# ..
# [world]
# .
